# %%
people = {
    "first": ['Jack', 'James', 'Liam', 'Steve', 'Oliver'],
    "last": ['Simons', 'Simons', 'Payne', 'Rogers', 'Simons'],
    "email":['jsim@demo.com', 'jkab@demo.com', 
             'lpayne@demo.com', 'captain@demo.com', 'o.simons@demo.com']
}

import pandas as pd

df = pd.DataFrame(people)
df
# Out:
#     first    last              email
# 0    Jack  Simons      jsim@demo.com
# 1   James  Simons      jkab@demo.com
# 2    Liam   Payne    lpayne@demo.com
# 3   Steve  Rogers   captain@demo.com
# 4  Oliver  Simons  o.simons@demo.com

# %% [markdown]
# # Sorting using sort_values()

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)
df
# Out:
#     first    last              email
# 0    Jack  Simons      jsim@demo.com
# 1   James  Simons      jkab@demo.com
# 4  Oliver  Simons  o.simons@demo.com
# 3   Steve  Rogers   captain@demo.com
# 2    Liam   Payne    lpayne@demo.com

# %%
df.sort_index( )
# ^ By index
# Out:
#     first    last              email
# 0    Jack  Simons      jsim@demo.com
# 1   James  Simons      jkab@demo.com
# 2    Liam   Payne    lpayne@demo.com
# 3   Steve  Rogers   captain@demo.com
# 4  Oliver  Simons  o.simons@demo.com

# %%
df['last'].sort_values()
# For a series
# Out:
# 2     Payne
# 3    Rogers
# 0    Simons
# 1    Simons
# 4    Simons
# Name: last, dtype: object

# %% [markdown]
# ## CSV

# %%
# setting an index beforehand
df = pd.read_csv('../../DevSurvey2020/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('../../DevSurvey2020/survey_results_schema.csv', index_col='Column')
# index_col -> setting the index 
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)
df[['Country', 'ConvertedComp']].head(60)
# Out:
#                 Country  ConvertedComp
# Respondent
# 62788       Afghanistan      1000000.0
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# 9839        Afghanistan        23328.0
# 63848       Afghanistan        23328.0
# 51862       Afghanistan        20950.0
# 51509       Afghanistan        20220.0
# 44484       Afghanistan        18660.0
# 15422       Afghanistan        18000.0
# 2932        Afghanistan        16335.0
# 26540       Afghanistan        13992.0
# 57269       Afghanistan        10884.0
# 26775       Afghanistan         8016.0
# 30568       Afghanistan         5448.0
# 30522       Afghanistan         4668.0
# 28811       Afghanistan         4509.0
# 34969       Afghanistan         4356.0
# 26857       Afghanistan         2328.0
# 33878       Afghanistan         1860.0
# 35753       Afghanistan          780.0
# 18049       Afghanistan          109.0
# ...

# %% [markdown]
# # Getting 10 highest salaries from our data

# %%
df['ConvertedComp'].nlargest(10)
# ^ getting the highest of a series
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# ^ getting the 10 highest and their corresponding data from a dframe
# nsmallest() is the opposite
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession       No  26.0
# 54263                          I am a developer by profession      Yes  29.0
# 43430                          I am a developer by profession      Yes  33.0
# 59279                          I am a developer by profession      Yes   NaN
# 46711                          I am a developer by profession      Yes   NaN
# 123                            I am a developer by profession      Yes  26.0
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 193                            I am a developer by profession      Yes  29.0
# 665                            I am a developer by profession      Yes  24.0
# 699         I am not primarily a developer, but I write co...      Yes  39.0
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# ...

# %% [markdown]
# # Sorting a dframe by a series

# %%
df.sort_values('Country')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 62788               I am a developer by profession      Yes   NaN        NaN
# 44697               I am a developer by profession      Yes   NaN        NaN
# 44556               I am a developer by profession       No   NaN         17
# 44555               I am a developer by profession       No   NaN         20
# 43966       I am a student who is learning to code      Yes  25.0         13
# ...                                            ...      ...   ...        ...
# 60055                                          NaN       No   NaN        NaN
# 61121                                          NaN      Yes   NaN        NaN
# 61570                                          NaN       No   NaN        NaN
# 61918                                          NaN      Yes   NaN        NaN
# 62605                                          NaN       No   NaN        NaN
#
# ...

# %% [markdown]
# # Sorting by multiple columns

# %%
df.sort_values(['Country', 'ConvertedComp'])
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession      Yes   NaN         13  Monthly
# 18049       I am a developer by profession      Yes   NaN         15   Yearly
# 35753       I am a developer by profession      Yes   NaN         18  Monthly
# 33878       I am a developer by profession      Yes   NaN         18  Monthly
# 26857       I am a developer by profession       No  25.0         20  Monthly
# ...                                    ...      ...   ...        ...      ...
# 60055                                  NaN       No   NaN        NaN      NaN
# 61121                                  NaN      Yes   NaN        NaN      NaN
# 61570                                  NaN       No   NaN        NaN      NaN
# 61918                                  NaN      Yes   NaN        NaN      NaN
# 62605                                  NaN       No   NaN        NaN      NaN
#
# ...
