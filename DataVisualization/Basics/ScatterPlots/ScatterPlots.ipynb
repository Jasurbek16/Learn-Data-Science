# %% [markdown]
# # Scatter Plots of the Rate of Satisfaction
# ### Used for showing the relationship between 2 sets of values and see if they're correlated

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(9, 6), dpi=80)

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
# ^ used for giving different colors for above dots
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
         538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

plt.scatter(x, y, s=sizes, c=colors, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)
# s -> size
# c -> color
# marker='X' <- change dots to crosses
# alpha is for the entire scatter
# linewidth is for the edgecolor
# cmap -> setting a color map when we want 
# -to change the def color from plot

cbar = plt.colorbar()
cbar.set_label('Service Liked')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Scatter Plot for Different Trending Videos on YouTube

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(9, 6), dpi=80)

plt.style.use('seaborn')

data = pd.read_csv('2019-05-31-data.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count, 
            likes,
            c=ratio,
            cmap='summer',
            edgecolor='black', 
            linewidth=1, 
            alpha=0.75)

cbar=plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

plt.xscale('log')
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()

plt.show()
